# %%
import requests
import json

# %%
my_json = json.load(open('./input.json', 'r'))

# %%
port_number =  9000
res = requests.post(f'http://localhost:{port_number}/predict', json=my_json)

# %%
json.loads(res.text)
# Out:
# [{'time': '2024-04-02T07:16:56', 'value': '6.474311'},
#  {'time': '2024-04-02T07:17:04', 'value': '5.7212057'},
#  {'time': '2024-04-02T07:17:12', 'value': '5.217967'},
#  {'time': '2024-04-02T07:17:20', 'value': '4.875037'},
#  {'time': '2024-04-02T07:17:28', 'value': '4.331279'},
#  {'time': '2024-04-02T07:17:36', 'value': '3.544986'},
#  {'time': '2024-04-02T07:17:44', 'value': '2.7508347'},
#  {'time': '2024-04-02T07:17:52', 'value': '2.0918343'},
#  {'time': '2024-04-02T07:18:00', 'value': '1.5410492'},
#  {'time': '2024-04-02T07:18:08', 'value': '1.3217728'},
#  {'time': '2024-04-02T07:18:16', 'value': '1.1706727'},
#  {'time': '2024-04-02T07:18:24', 'value': '1.3187897'},
#  {'time': '2024-04-02T07:18:32', 'value': '1.1615098'},
#  {'time': '2024-04-02T07:18:40', 'value': '1.1633751'},
#  {'time': '2024-04-02T07:18:48', 'value': '1.3219712'},
#  {'time': '2024-04-02T07:18:56', 'value': '1.5047143'},
#  {'time': '2024-04-02T07:19:04', 'value': '1.6893609'},
# ...
